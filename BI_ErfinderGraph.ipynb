# %%
import os
import pandas as pd
from collections import Counter, OrderedDict
import networkx as nx
import nx_altair as nxa
import altair as alt
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib.pyplot as plt

# %%
# load data
filepath = os.path.join(os.getcwd(), 'Datensatz_Erfinder_raw.csv')
data = pd.read_csv(filepath , sep = ";")

# %%
# count companies patents
patent_counter = Counter()
for row in data.itertuples():    
    row_df = pd.DataFrame(row).transpose().drop(0, axis=1)
    row_df.columns = data.columns            
    patent_counter[row_df["Anmelder/Inhaber"][0]] += 1
sorted_most_common_companies = sorted(patent_counter, key=patent_counter.get, reverse=True)

# get most common 10 companies
n_most_common_companies = sorted_most_common_companies[0:10]
n_most_common_companies_df = data[data['Anmelder/Inhaber'].isin(n_most_common_companies)]

n_most_common_companies_df
# Out:
#       \t\tlfd. Nummer Veröffentlichungs-Nummer Anmeldedatum  \
# 169               170         EP000003582168A1   14.06.2019
# 175               176         EP000003570244A1   20.05.2019
# 188               189         EP000003537363A1   05.03.2019
# 224               225         EP000003428863A1   06.07.2018
# 288               289         US020210119804A1   18.10.2019
# ...               ...                      ...          ...
# 3195             3196         WO002016186873A1   06.05.2016
# 3196             3197         WO002016186872A1   06.05.2016
# 3197             3198         WO002016186870A1   06.05.2016
# 3198             3199         WO002016186869A1   06.05.2016
# 3199             3200         WO002016175914A2   26.02.2016
#
#                                                Erfinder  \
# 169             EDWARDS JOSHUA, US; MOSSOBA MICHAEL, US
# 175                 PHILLIPS JEREMY, US; TRAN KURRY, US
# 188   MARTIN ROBERT, US; MILLER WALTER AVERY, US; SM...
# 224                               SILVERSTRE CARLOS, US
# 288   DESHPANDE AJAY ASHOK, US; HARSHA PAVITHRA, US;...
# ...                                                 ...
# 3195                           DAVIS STEVEN CHARLES, US
# 3196                           DAVIS STEVEN CHARLES, US
# 3197                           DAVIS STEVEN CHARLES, US
# 3198  DAVIS STEVEN CHARLES, US; TETALI ASHISH RAGHAV...
# 3199                     CLARK ADAM, US; WAGNER KIM, US
#
#                                        Anmelder/Inhaber  \
# 169                        CAPITAL ONE SERVICES LLC, US
# 175                        CAPITAL ONE SERVICES LLC, US
# 188                        CAPITAL ONE SERVICES LLC, US
# 224   AMERICAN EXPRESS TRAVEL RELATED SERVICES CO IN...
# 288                                             IBM, US
# ...                                                 ...
# 3195                   MASTERCARD INTERNATIONAL INC, US
# 3196                   MASTERCARD INTERNATIONAL INC, US
# 3197                   MASTERCARD INTERNATIONAL INC, US
# 3198                   MASTERCARD INTERNATIONAL INC, US
# 3199                           VISA INT SERVICE ASS, US
#
#                                                   Titel  \
# 169    [DE] HALBPRIVATE VIRTUELLE BLOCKKETTENWÄHRUNG...
# 175    [DE] SICHERES SYSTEM  [EN] A SECURE SYSTEM  [...
# 188    [DE] SYSTEME UND VERFAHREN ZUR VERWENDUNG VON...
# 224    [DE] FONDS-ÜBERTRAGUNGSDIENST FÜR MEHRERE VER...
# 288           [EN] FRESHNESS VISIBILITY IN SUPPLY-CHAIN
# ...                                                 ...
# 3195   [EN] METHOD AND SYSTEM FOR PROCESSING BLOCKCH...
# 3196   [EN] METHOD AND SYSTEM FOR FRAUD CONTROL OF B...
# 3197   [EN] METHOD AND SYSTEM FOR LINKAGE OF BLOCKCH...
# 3198   [EN] METHOD AND SYSTEM FOR INTEGRATION OF MAR...
# 3199   [EN] TRANSACTION SIGNING UTILIZING ASYMMETRIC...
#
#                                         Zusammenfassung Länderkürzel    Land  \
# 169    [EN]  A first merchant node on a semi-private...           EP  Europa
# 175    [EN]  A device may receive application questi...           EP  Europa
# 188    [EN]  Disclosed is a distributed ledger proce...           EP  Europa
# 224    [EN]  Systems, methods, and articles of manuf...           EP  Europa
# 288    [EN]  An example operation may include one or...           US     USA
# ...                                                 ...          ...     ...
# 3195   [EN]  A method for authorizing a blockchain-b...           WO    WIPO
# 3196   [EN]  A method for Sinking blockchain transac...           WO    WIPO
# 3197   [EN]  A method for managing fractional reserv...           WO    WIPO
# 3198   [EN]  A method for authorization of a blockch...           WO    WIPO
# 3199   [EN]  Embodiments relate to systems, apparatu...           WO    WIPO
#
#      Prozessstand Anmelderländerkürzel Anmelderland
# 169             A                   US          USA
# 175             A                   US          USA
# 188             A                   US          USA
# 224             A                   US          USA
# 288             A                   US          USA
# ...           ...                  ...          ...
# 3195            A                   US          USA
# 3196            A                   US          USA
# 3197            A                   US          USA
# 3198            A                   US          USA
# 3199            A                   US          USA
#
# [693 rows x 12 columns]

# %%
normalized_data = []
# fill patents inventors if they are not filled
n_most_common_companies_df['Erfinder'] = n_most_common_companies_df['Erfinder'].fillna(value='no Inventor')
# loop over most common companies
for row in n_most_common_companies_df.itertuples():
    row_df = pd.DataFrame(row).transpose().drop(0, axis=1)
    row_df.columns = n_most_common_companies_df.columns
    
    # get inventors normalized 
    inventors = row_df["Erfinder"][0].split(';')       
    # create new line for every Inventor and applicant
    for inventor in inventors:
        normalized_row = [row_df["Veröffentlichungs-Nummer"][0],inventor.strip(), row_df["Anmelder/Inhaber"][0]]
        normalized_data.append(normalized_row)

# drop duplicates based on inventor and applicant
normalized_data_df = pd.DataFrame(normalized_data, columns=["Veröffentlichungs-Nummer", "Erfinder", "Anmelder/Inhaber"]).drop_duplicates(subset=["Erfinder", "Anmelder/Inhaber"])
normalized_data_df.to_csv("Datensatz_Erfinder_normalisiert.csv", sep=";")
# Out:
# <ipython-input-50-0013fd178595>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n_most_common_companies_df['Erfinder'] = n_most_common_companies_df['Erfinder'].fillna(value='no Inventor')

# %%
# create graph from edgelist
inventor_graph = nx.from_pandas_edgelist(normalized_data_df,
source = "Erfinder",
target = "Anmelder/Inhaber")

# add "Erfinder" as node attribute
nx.set_node_attributes(inventor_graph, pd.Series(normalized_data_df.Erfinder).to_dict())

# %%
#draw networkx altair chart with "Erfinder" in tooltips
alt.data_transformers.disable_max_rows()
chart = nxa.draw_networkx(
    inventor_graph,
    node_color='Anmelder/Inhaber:N',
    cmap='viridis',
    edge_color='black',
    node_size=100,
    node_tooltip = ['Erfinder:N']
).properties(
    width=600,
    height=600
).interactive()
chart
# Out:
# alt.LayerChart(...)
